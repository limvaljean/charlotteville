# %% [markdown]
# #### My ultimate goal is simple enough: I will be looking at what Twitter users said about a violent clash that broke out in Charlottesville, that is, major key topics that they discussed. I am also interested in finding out their tweeting behavior as well, such as when they tweeted their message, who the influential Twitter users were, and who was most active in the conversation.
#
# I used Twitter data available from 15 August via Kaggle, and I looked at 50,000 tweets. I uploaded them onto pandas and clean textual data using NLTK
#
# As usual, I start out by loading all the packages

# %%
# %matplotlib inline 
import nltk
import string
import pandas as pd
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter


tweets = pd.read_csv('aug15_sample.csv')

# %% [markdown]
# #### Tokening text and getting rid of all the stopwords. Finally store most frequently mentioned keywords in rslt variable.

# %%
# clustering algorithms 
# from http://ahmedbesbes.com/how-to-mine-newsfeed-data-and-extract-interactive-insights-in-python.html

pd.options.mode.chained_assignment = None
# nltk for nlp
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
# list of stopwords like articles, preposition
stop = set(stopwords.words('english'))
from string import punctuation
from collections import Counter

def tokenizer(text):
    try:
        tokens_ = [word_tokenize(sent) for sent in sent_tokenize(text)]
        
        #RE_stopwords = r'\b(?:{})\b'.format('|'.join(stop))
        
        tokens = []
        for token_by_sent in tokens_:
            tokens += token_by_sent

        tokens = list(filter(lambda t: t.lower() not in stop, tokens))
        tokens = list(filter(lambda t: t not in punctuation, tokens))
        tokens = list(filter(lambda t: t not in [u"'s", u"n't", u"...", u"''", u'``', u'amp', u'https',
                                                u'via', u"'re", u"'m"], tokens))
        #tokens = [w.replace(r'\|', ' ') for w in tokens]
        #tokens = [w.replace(RE_stopwords, ' ') for w in tokens]
        #tokens = [w.replace(r"(&amp)|,|;|\"|\.|\?|’|!|'|:|-|\\|/|https", ' ') for w in tokens]
    
        filtered_tokens = []
        for token in tokens:
            if re.search('[a-zA-Z]', token):
                filtered_tokens.append(token)

        filtered_tokens = list(map(lambda token: token.lower(), filtered_tokens))

        return filtered_tokens
    except Error as e:
        print(e)
        
        
tweets['tokens'] = tweets['full_text'].map(tokenizer)

# %%
tweets['tokens'].head(10)
# Out:
# 0    [white, wo, go, anywhere, near, alabama, //t.c...
# 1    [another, chief, leaves, trump, manufacturing,...
# 2    [senwarren, fauxcohontas, condemned, participa...
# 3    [//t.co/za33wqp977, news, histórico, líder, de...
# 4    [davidemck59, cathymdonker, southoflife75, sus...
# 5    [depuis, le, drame, de, charlottesville, il, s...
# 6         [try, watch, ca, stomach, //t.co/0z9vkcssna]
# 7                             [get, //t.co/dsjqizqmav]
# 8    [folks, protested, vs, nazis, charlottesville,...
# 9    [charlottesville, murder, suspect, failed, bas...
# Name: tokens, dtype: object

# %%
tweets['tokens'] = tweets['tokens'].map(lambda L: " ".join(L))
words = (tweets['tokens']
           .str.cat(sep=' ')
           .split()
        )

top_N = 50

rslt = pd.DataFrame(Counter(words).most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

rslt = rslt.iloc[1:]
rslt
# Out:
#                  Frequency
# Word
# trump                11392
# white                 3763
# realdonaldtrump       2786
# violence              2568
# sides                 2175
# people                2135
# news                  2002
# impeachtrump          1931
# president             1799
# obama                 1710
# donald                1597
# response              1559
# one                   1361
# like                  1351
# nazis                 1301
# watch                 1298
# supremacists          1285
# potus                 1280
# racist                1226
# tweet                 1217
# antifa                1165
# right                 1059
# hate                  1041
# nazi                   998
# de                     988
# blame                  967
# says                   966
# vice                   965
# rally                  948
# youtube                919
# know                   916
# cnn                    902
# press                  873
# ...

# %% [markdown]
# #### Here comes the top keywords uttered by Twitter users
#
# These are the most frequently mentioned keywords in the 15 Aug Twitter conversation.  Notice that there are a lot reference to the US President, such as “trump”, “@realdonaldtrump”, “sides”, “#impeachtrump”.  I can’t make a definite conclusion on anything, but people do believe that President Trump is heavily involved with this incident, especially in light of the remarks in which he blamed both “sides” of the picket line for the violent clash.

# %%
sns.set_style("darkgrid")
plt.rcParams["figure.figsize"] = [30.0, 20.0]
ax = sns.barplot(y=rslt.index, x='Frequency', data=rslt)
ax.set_xlabel("Frequency",fontsize=20)
ax.set_ylabel("Words",fontsize=20)
ax.tick_params(labelsize=30)

# %% [markdown]
# #### Most frequently used hashtags

# %%
#hashtags = hashtags[~hashtags.isnull()]
tags = (tweets['hashtags']
           .str.lower()
           .str.cat(sep=' ')
           .split()
)

hashtgs = pd.DataFrame(Counter(tags).most_common(top_N),
                    columns=['Hashtags', 'Frequency']).set_index('Hashtags')
hashtgs = hashtgs.iloc[1:]
hashtgs
# Out:
#                                   Frequency
# Hashtags
# "impeachtrump"                         1714
# "trump"                                 890
# "maga"                                  383
# "resist"                                269
# "antifa"                                242
# "news"                                  203
# "altright"                              165
# "impeach45"                             154
# "quitthecouncil"                        151
# "impeach"                               146
# "theresistance"                         138
# "impeachtrumpnow"                       133
# "altleft"                               133
# "heatherheyer"                          126
# "whitesupremacists"                     116
# "potus"                                 116
# "racism"                                112
# "bothsides"                             105
# "fakenews"                              102
# "kkk"                                   100
# ...

# %% [markdown]
# #### Plotting most frequently used hashtags
#
# Once again, President Trump figures heavily in the hashtag stream, and they are mostly negative, as illustrated in such examples as “impeachtrump”, “impeach45”, “impeach”, “impeachtrumpnow”

# %%
sns.set_style("darkgrid")
ax = sns.barplot(y=hashtgs.index, x='Frequency', data=hashtgs)
ax.set_xlabel("Frequency",fontsize=20)
ax.set_ylabel("Hashtag",fontsize=20)
ax.tick_params(labelsize=30)

# %%
hashtgs
# Out:
#                                   Frequency
# Hashtags
# "impeachtrump"                         1714
# "trump"                                 890
# "maga"                                  383
# "resist"                                269
# "antifa"                                242
# "news"                                  203
# "altright"                              165
# "impeach45"                             154
# "quitthecouncil"                        151
# "impeach"                               146
# "theresistance"                         138
# "impeachtrumpnow"                       133
# "altleft"                               133
# "heatherheyer"                          126
# "whitesupremacists"                     116
# "potus"                                 116
# "racism"                                112
# "bothsides"                             105
# "fakenews"                              102
# "kkk"                                   100
# ...

# %%
tweets['created_at'] = pd.to_datetime(tweets['created_at'])

# %%
tweets = tweets.set_index('created_at')

# %%
df = tweets[['id']]
tweet_volume = df.resample('10min').count()

# %% [markdown]
# #### Tweets were collected between 0100 GMT and 0400 GMT (yeah a very limited time span, I know), and the graph shows the tweet traffic trend broken down by 10-minute interval. You can see that the tweet traffic shot up at 0120 GMT and maintained the momentum until 0350 GMT when it fell markedly.

# %%
ax = sns.pointplot(x=tweet_volume.index, y='id', data=tweet_volume)
ax.set_xlabel("When did they tweet?",fontsize=20)
ax.set_ylabel("How many tweets?",fontsize=20)

ax.tick_params(labelsize=25)

for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
influential = tweets[['user_name', 'followers_count']]

# %%
influential = influential.sort_values('followers_count', ascending=False)

# %% [markdown]
# #### We have a list of users in the conversation who has the biggest number of followers. Not surprisingly, all of them were media organizations such as CNN or Reuters.

# %%
influential.groupby('user_name').first().sort_values(by='followers_count', ascending=False)[:10]
# Out:
#                   followers_count
# user_name
# CNN                      37067971
# Reuters Top News         18494616
# Fox News                 15636365
# MTV                      15473246
# TIME                     14518616
# ABC News                 11495209
# Washington Post          10908284
# NDTV                      9975479
# Mashable                  9205958
# People                    7817745

# %% [markdown]
# #### These are the users who tweeted the most over the span of 3 hours. We have three users who tweeted over 100 times in 3 hours! Some people are really passionate about this topic.

# %%
tweets['screen_name'].value_counts()[:10]
# Out:
# socalhomes411      121
# corrigan_david     113
# ArisaRoyal         103
# BinkyDLA            86
# Rightingtheship     82
# Foods4u             70
# partermaytr2        45
# The1stLadyLove      43
# GrasslandDesign     42
# ToBeSafeNSound      37
# Name: screen_name, dtype: int64

# %%
for full_text, tokens in zip(tweets['full_text'].head(5), tweets['tokens'].head(5)):
    print('full text:', full_text)
    print('tokens:', tokens)
    print()
# Out:
# full text: I'm white and I won't go anywhere near Alabama. https://t.co/onuzwbOsVb
# tokens: white wo go anywhere near alabama //t.co/onuzwbosvb
#
# full text: Another chief leaves Trump's manufacturing council
# https://t.co/NqZDz9WMkw
# tokens: another chief leaves trump manufacturing council //t.co/nqzdz9wmkw
#
# full text: @SenWarren No he didn't #fauxcohontas! He condemned those who participated in the violence at #Charlottesville on both sides!
# tokens: senwarren fauxcohontas condemned participated violence charlottesville sides
#
# full text: https://t.co/zA33WQp977 #News Histórico líder de KKK alaba a Trump por ‘decir la verdad’ de Charlottesville https://t.co/Y5fOI9FYLm
# tokens: //t.co/za33wqp977 news histórico líder de kkk alaba trump por decir la verdad de charlottesville //t.co/y5foi9fylm
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# min_df is minimum number of documents that contain a term t
# max_features is maximum number of unique tokens (across documents) that we'd consider
# TfidfVectorizer preprocesses the descriptions using the tokenizer we defined above

vectorizer = TfidfVectorizer(min_df=10, max_features=10000, tokenizer=tokenizer, ngram_range=(1, 2))
vz = vectorizer.fit_transform(list(tweets['full_text']))

# %%
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf.columns = ['tfidf']

# %%
tfidf.tfidf.hist(bins=50, figsize=(15,7))

# %%
tfidf.sort_values(by=['tfidf'], ascending=False).head(30)
# Out:
#                            tfidf
# 'a                      9.421903
# charlottesville women   9.421903
# concern                 9.421903
# condemn 'rightwing      9.421903
# trump thinks            9.421903
# confused happened       9.421903
# consequence             9.421903
# option                  9.421903
# oppression              9.421903
# opposing evil           9.421903
# contact                 9.421903
# trump spoke             9.421903
# continuing              9.421903
# cooper trump            9.421903
# cos                     9.421903
# could say               9.421903
# onto                    9.421903
# courageous              9.421903
# one time                9.421903
# trump president         9.421903
# oliver charlottesville  9.421903
# old man                 9.421903
# criticizing trump       9.421903
# oh please               9.421903
# culpar los              9.421903
# trump name              9.421903
# royblunt                9.421903
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from sklearn.cluster import MiniBatchKMeans

num_clusters = 10
kmeans_model = MiniBatchKMeans(n_clusters=num_clusters, init='k-means++', n_init=1, 
                         init_size=1000, batch_size=1000, verbose=False, max_iter=1000)
kmeans = kmeans_model.fit(vz)
kmeans_clusters = kmeans.predict(vz)
kmeans_distances = kmeans.transform(vz)

# %% [markdown]
# #### I used k-means clustering algorithms to generate a list of words that appear frequently together, and the results are shown above.
#
# #### You can see that there is a thread of conversation that we couldn’t detect from the word frequency list. One example of this is Cluster #3, where a pocket of people expressed their displeasure with CNN coverage. K-means clustering is surely a great way to complement our word frequency tally.

# %%
sorted_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(num_clusters):
    print("Cluster %d:" % i)
    aux = ''
    for j in sorted_centroids[i, :10]:
        aux += terms[j] + ' | '
    print(aux)
    print()
# Out:
# Cluster 0:
# watch | thread | fuck | disgusting | must | must watch | much | please | fucking | please watch |
#
# Cluster 1:
# sides | sides charlottesville | trump | blame | blames | violence | charlottesville | charlottesville violence | blames sides | trump blames |
#
# Cluster 2:
# charlottesville | trump | realdonaldtrump | violence | president | like | potus | white | antifa | nazis |
#
# Cluster 3:
# impeachtrump | impeachtrump charlottesville | charlottesville impeachtrump | charlottesville | realdonaldtrump | resist | trump | theresistance | impeachtrumpnow | realdonaldtrump impeachtrump |
#
# Cluster 4:
# fox news | fox | news | twitter | press conference | charlottesville press | conference | press | roots | conference roots |
#
# Cluster 5:
# charlottesville | obama | tweet | response | obama charlottesville | vice | charlottesville response | news | most-liked | most-liked tweet |
#
# Cluster 6:
# ...
